# %% [markdown]
# # 03. OLAP Analysis: Tương quan Sức khỏe tâm thần và Kinh tế - Xã hội
# **Mục tiêu:** Trả lời các câu hỏi nghiên cứu về mối liên hệ giữa GDP bình quân và tỷ lệ mắc rối loạn tâm lý toàn cầu.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

PROC_DIR = Path('../data/03_processed')
df_mh = pd.read_csv(PROC_DIR / 'fact_mental_health.csv')
df_se = pd.read_csv(PROC_DIR / 'fact_socioeconomic.csv')
df_loc = pd.read_csv(PROC_DIR / 'dim_location.csv')
df_cause = pd.read_csv(PROC_DIR / 'dim_cause.csv')

# Merge phuc vu phan tich
df_merged = df_mh.merge(df_loc, on='location_key').merge(df_se, on=['location_key', 'time_key'])
print('Shape phan tich hop nhat:', df_merged.shape)
